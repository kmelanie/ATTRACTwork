# %%
import pandas as pnd

data_energy=pnd.read_csv("energy_scores-sep_wdiff.csv", sep ="\t")
data_energy.describe()
print(data_energy)
# Out:
#       PDB  rigid_energy_score.start      end.  rigid_energy_score_refe.start  \
# 0    1A2K                 32827.166   109.172                        -18.252
# 1    1ACB                   394.611   -19.340                        -25.516
# 2    1AHW                    -5.139   -20.475                        -24.520
# 3    1AK4                   256.465   -20.700                        -21.501
# 4    1AKJ                    64.045   -16.822                        -23.760
# ..    ...                       ...       ...                            ...
# 199  4JCV                 20719.886  6214.058                        -23.330
# 200  4LW4                  1493.736   -15.340                        -19.528
# 201  4M76                     4.532   -11.589                         -9.461
# 202  7CEI                   -24.988   -28.429                        -28.237
# 203  9QFW                   -16.246   -23.268                        -22.704
#
#      end..1  energy_score.start     end..2  energy_score_refe.start  \
# 0   -24.144            8320.682    296.600                  436.879
# 1   -27.641          485621.320  61564.334               484140.401
# 2   -30.628             208.226    139.715                  228.848
# 3   -22.805             350.191     93.724                  152.160
# 4   -26.711          225646.058  10448.666               278167.277
# ..      ...                 ...        ...                      ...
# 199 -38.667          161514.012   6804.662               153335.927
# 200 -22.289            1865.025    337.187                  364.988
# 201 -10.846             244.413    202.559                  213.004
# 202 -34.718             261.374    219.217                  238.201
# 203 -26.706             325.656    278.792                  324.839
#
#         end..3  restraining_energy_score.start     end..4  \
# 0      278.623                         409.444    369.548
# 1    65866.201                      485253.020  58978.268
# 2      152.584                         266.804    220.970
# 3       83.378                         119.230    115.515
# 4    20860.988                      225651.115  10002.649
# ..         ...                             ...        ...
# 199   5607.351                      155139.369   6468.688
# 200    266.750                         426.310    405.011
# 201    178.957                         267.306    237.044
# 202    203.989                         304.016    267.901
# 203    227.981                         367.905    324.231
#
#      restraining_energy_score_refe.start     end..5  \
# 0                                512.433    356.925
# 1                             484183.043  63881.052
# 2                                305.589    244.734
# 3                                181.381    111.505
# 4                             278259.261  20570.762
# ..                                   ...        ...
# 199                           153477.448   5519.939
# 200                              426.269    341.930
# 201                              246.460    216.336
# 202                              286.891    262.161
# 203                              374.279    279.620
#
#      energy_score_wo_restraining.start    end..6  \
# 0                             7911.238   -72.948
# 1                              368.300  2586.066
# 2                              -58.578   -81.255
# 3                              230.961   -21.791
# 4                               -5.057   446.017
# ..                                 ...       ...
# 199                           6374.643   335.974
# 200                           1438.715   -67.824
# 201                            -22.893   -34.485
# 202                            -42.642   -48.684
# 203                            -42.249   -45.439
#
#      energy_score_refe_wo_restraining.start    end..7  \
# 0                                   -75.554   -78.302
# 1                                   -42.642  1985.149
# 2                                   -76.741   -92.150
# 3                                   -29.221   -28.127
# 4                                   -91.984   290.226
# ..                                      ...       ...
# 199                                -141.521    87.412
# 200                                 -61.281   -75.180
# 201                                 -33.456   -37.379
# 202                                 -48.690   -58.172
# 203                                 -49.440   -51.639
#
#      delta_energy_score_end_flex_minus_rig
# 0                                 -182.120
# 1                                 2605.406
# 2                                  -60.780
# 3                                   -1.091
# 4                                  462.839
# ..                                     ...
# 199                              -5878.084
# 200                                -52.484
# 201                                -22.896
# 202                                -20.255
# 203                                -22.171
#
# [204 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
def energy_horizontal_barplot(rigid_score, flexible_score):
    sns.set(style="whitegrid")

    # Initialize the matplotlib figure
    f, ax = plt.subplots(figsize=(6, 25))

    # Plot the crashes where alcohol was involved
    sns.set_color_codes("pastel")
    sns.barplot(x=flexible_score, y="PDB", data=data_energy,
                label="Flexible", color="g")

    # Plot the total crashes
    sns.set_color_codes("muted")
    sns.barplot(x=rigid_score, y="PDB", data=data_energy,
                label="Rigid", color="b")



    # Add a legend and informative axis label
    ax.legend(ncol=2, loc="lower right", frameon=True)
    ax.set(xlim=(-150, 200), ylabel="",
           xlabel="Energy score [kcal/mol]")

    ax.set_yticklabels(ax.get_yticklabels(), fontsize=7)
    sns.despine(left=True, bottom=True)

energy_horizontal_barplot("rigid_energy_score.start","energy_score_wo_restraining.start")
energy_horizontal_barplot("end.","end..6")
energy_horizontal_barplot("rigid_energy_score_refe.start","energy_score_refe_wo_restraining.start")
energy_horizontal_barplot("end..1","end..7")

# %%
data_irmsd=pnd.read_csv("IRMSD_sep.csv", sep="\t")
data_irmsd.describe()
data_all=pnd.read_csv("all_data_sep.csv", sep="\t")
print(data_all)
data_all.describe()
# Out:
#       PDB  rigid_energy_score_start  rigid_energy_score_end  \
# 0    1A2K                 32827.166                 109.172
# 1    1ACB                   394.611                 -19.340
# 2    1AHW                    -5.139                 -20.475
# 3    1AK4                   256.465                 -20.700
# 4    1AKJ                    64.045                 -16.822
# ..    ...                       ...                     ...
# 199  4JCV                 20719.886                6214.058
# 200  4LW4                  1493.736                 -15.340
# 201  4M76                     4.532                 -11.589
# 202  7CEI                   -24.988                 -28.429
# 203  9QFW                   -16.246                 -23.268
#
#      rigid_energy_score_refe_start  rigid_energy_score_refe_end  \
# 0                          -18.252                      -24.144
# 1                          -25.516                      -27.641
# 2                          -24.520                      -30.628
# 3                          -21.501                      -22.805
# 4                          -23.760                      -26.711
# ..                             ...                          ...
# 199                        -23.330                      -38.667
# 200                        -19.528                      -22.289
# 201                         -9.461                      -10.846
# 202                        -28.237                      -34.718
# 203                        -22.704                      -26.706
#
#      rigid_intra_iRMSD  rigid_intra_refe_iRMSD  rigid_inter_iRMSD_start  \
# 0                3.827                   0.783                    1.066
# 1                2.584                   0.267                    2.399
# 2                0.652                   0.600                    0.925
# 3                1.879                   0.415                    0.920
# 4                2.329                   0.393                    1.197
# ..                 ...                     ...                      ...
# 199              0.705                   1.401                    1.995
# 200              2.801                   1.102                    1.678
# 201              1.129                   0.395                    0.639
# 202              0.685                   0.674                    0.771
# 203              1.637                   1.298                    1.016
#
#      rigid_inter_iRMSD_end  intra_rmsca  ...  looponly_inter_rmsca_start  \
# 0                    1.370       1.6763  ...                      0.3658
# 1                    2.434       5.9786  ...                      2.0873
# 2                    1.055       0.5156  ...                      0.6402
# 3                    0.985       1.4780  ...                      1.0576
# 4                    1.197       4.5633  ...                      1.2410
# ..                     ...          ...  ...                         ...
# 199                  2.346       2.5639  ...                      0.7866
# 200                  1.920       1.2538  ...                      2.7329
# 201                  0.636       0.4643  ...                      0.3287
# 202                  0.950       0.6154  ...                      0.4986
# 203                  1.553       0.9829  ...                      2.3246
#
#      looponly_inter_rmsca_end  energy_score_start  energy_score_end  \
# 0                      0.7545            8320.682           296.600
# 1                      8.2808          485621.320         61564.334
# 2                      0.8803             208.226           139.715
# 3                      1.5316             350.191            93.724
# 4                      5.8030          225646.058         10448.666
# ..                        ...                 ...               ...
# 199                    5.9863          161514.012          6804.662
# 200                    2.6522            1865.025           337.187
# 201                    0.7817             244.413           202.559
# 202                    0.7068             261.374           219.217
# 203                    2.4675             325.656           278.792
#
#      energy_score_refe_start  energy_score_refe_end  \
# 0                    436.879                278.623
# 1                 484140.401              65866.201
# 2                    228.848                152.584
# 3                    152.160                 83.378
# 4                 278167.277              20860.988
# ..                       ...                    ...
# 199               153335.927               5607.351
# 200                  364.988                266.750
# 201                  213.004                178.957
# 202                  238.201                203.989
# 203                  324.839                227.981
#
#      restraining_energy_score_start  restraining_energy_score_end  \
# 0                           409.444                       369.548
# 1                        485253.020                     58978.268
# 2                           266.804                       220.970
# 3                           119.230                       115.515
# 4                        225651.115                     10002.649
# ..                              ...                           ...
# 199                      155139.369                      6468.688
# 200                         426.310                       405.011
# 201                         267.306                       237.044
# 202                         304.016                       267.901
# 203                         367.905                       324.231
#
#      restraining_energy_score_refe_start  restraining_energy_score_refe_end
# 0                                512.433                            356.925
# 1                             484183.043                          63881.052
# 2                                305.589                            244.734
# 3                                181.381                            111.505
# 4                             278259.261                          20570.762
# ..                                   ...                                ...
# 199                           153477.448                           5519.939
# 200                              426.269                            341.930
# 201                              246.460                            216.336
# 202                              286.891                            262.161
# 203                              374.279                            279.620
#
# [204 rows x 33 columns]
#        rigid_energy_score_start  rigid_energy_score_end  \
# count              2.040000e+02              204.000000
# mean               4.693327e+09              207.689431
# std                6.684363e+10             2266.358087
# min               -2.498800e+01              -34.064000
# 25%                3.031750e+01              -20.499000
# 50%                9.504195e+02              -16.411000
# 75%                1.765983e+04              -11.378750
# max                9.547297e+11            31391.229000
#
#        rigid_energy_score_refe_start  rigid_energy_score_refe_end  \
# count                     204.000000                   204.000000
# mean                      -22.142686                   -27.336912
# std                         8.350745                     7.340281
# min                       -40.724000                   -47.533000
# 25%                       -27.323000                   -32.181750
# 50%                       -21.865000                   -26.927500
# 75%                       -17.444500                   -22.307750
# max                        14.828000                    -8.823000
#
#        rigid_intra_iRMSD  rigid_intra_refe_iRMSD  rigid_inter_iRMSD_start  \
# count         204.000000              204.000000               204.000000
# mean            3.605098                0.626882                 1.524647
# std             6.503469                0.328019                 1.283245
# min             0.334000                0.135000                 0.204000
# 25%             1.071250                0.400500                 0.771000
# 50%             1.692500                0.548000                 1.087000
# 75%             2.980500                0.743000                 1.992000
# max            50.647000                1.813000                 9.063000
#
#        rigid_inter_iRMSD_end  intra_rmsca  intra_refe_rmsca  ...  \
# count             204.000000   204.000000        204.000000  ...
# mean                1.702123     2.759684          2.278737  ...
# std                 1.223196     2.951305          3.485915  ...
# min                 0.372000     0.117900          0.327400  ...
# 25%                 0.959000     1.027575          0.698225  ...
# 50%                 1.392500     1.739800          1.012200  ...
# 75%                 2.040000     3.178600          2.317850  ...
# max                 9.012000    23.083200         29.933300  ...
#
#        looponly_inter_rmsca_start  looponly_inter_rmsca_end  \
# count                  204.000000                204.000000
# mean                     1.228138                  2.314528
# std                      1.333457                  2.122385
# min                      0.081300                  0.299800
# 25%                      0.504900                  0.885400
# 50%                      0.852950                  1.476000
# 75%                      1.547475                  2.890825
# max                     14.497800                 14.645900
#
#        energy_score_start  energy_score_end  energy_score_refe_start  \
# count        2.040000e+02        204.000000             2.040000e+02
# mean         5.406860e+06      18175.600760             9.198065e+04
# std          5.485248e+07      53769.865804             2.180174e+05
# min          1.285500e+02         58.771000             6.875500e+01
# 25%          7.803060e+02        224.951500             2.798167e+02
# 50%          5.023894e+03        603.616500             1.909865e+03
# 75%          1.743829e+05       3933.722000             3.348775e+04
# max          7.748610e+08     519640.228000             1.320013e+06
#
#        energy_score_refe_end  restraining_energy_score_start  \
# count             204.000000                    2.040000e+02
# mean            17620.678985                    9.226954e+04
# std             53214.327668                    2.192081e+05
# min                43.528000                    1.076430e+02
# 25%               195.937750                    3.133243e+02
# 50%               432.504000                    1.524754e+03
# 75%              3582.796500                    4.144996e+04
# max            485545.057000                    1.372654e+06
#
#        restraining_energy_score_end  restraining_energy_score_refe_start  \
# count                    204.000000                         2.040000e+02
# mean                   17859.924098                         9.205255e+04
# std                    52685.074943                         2.180221e+05
# min                       83.796000                         7.749700e+01
# 25%                      286.253000                         3.346778e+02
# 50%                      575.622500                         1.982494e+03
# 75%                     3714.418750                         3.359441e+04
# max                   503449.200000                         1.320057e+06
#
#        restraining_energy_score_refe_end
# count                         204.000000
# mean                        17386.843186
# std                         52449.757316
# min                            72.822000
# 25%                           272.494000
# 50%                           541.278500
# 75%                          3653.156750
# max                        480358.600000
#
# [8 rows x 32 columns]

# %%
def iRMSD_starttoend_horizontal_barplot(rigid_iRMSD, flexible_iRMSD):
    sns.set(style="whitegrid")

    # Initialize the matplotlib figure
    f, ax = plt.subplots(figsize=(6, 25))

    # Plot the iRMSD start value
    sns.set_color_codes("pastel")
    sns.barplot(x=flexible_iRMSD, y="PDB", data=data_all,
                label="FLEXIBLE", color="g")

    # Plot the iRMSD end value
    sns.set_color_codes("muted")
    sns.barplot(x=rigid_iRMSD, y="PDB", data=data_all,
                label="RIGID", color="b")



    # Add a legend and informative axis label
    ax.legend(ncol=2, loc="lower right", frameon=True)
    ax.set(xlim=(0, 10), ylabel="",
           xlabel="inter-iRMSD [A]")

    ax.set_yticklabels(ax.get_yticklabels(), fontsize=7)
    sns.despine(left=True, bottom=True)

iRMSD_starttoend_horizontal_barplot("inter_iRMSD_end","rigid_inter_iRMSD_end")
plt.savefig("inter-iRMSD_end.pdf")

# %%
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 25))

# Plot the crashes where alcohol was involved
sns.set_color_codes("pastel")
sns.barplot(x="end..7", y="PDB", data=data_energy,
            label="Flexible", color="b")

# Plot the total crashes
sns.set_color_codes("muted")
sns.barplot(x="end.", y="PDB", data=data_energy,
            label="Rigid", color="b")



# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(-150, 200), ylabel="",
       xlabel="Energy score [kcal/mol]")

ax.set_yticklabels(ax.get_yticklabels(), fontsize=7)
sns.despine(left=True, bottom=True)

# %%
print(list(data_all['PDB']))
# Out:
# ['1A2K', '1ACB', '1AHW', '1AK4', '1AKJ', '1ATN', '1AVX', '1AY7', '1AZS', '1B6C', '1BJ1', '1BKD', '1BUH', '1BVK', '1BVN', '1CGI', '1D6R', '1DFJ', '1DQJ', '1E4K', '1E6E', '1E6J', '1E96', '1EAW', '1EER', '1EFN', '1EWY', '1EZU', '1F34', '1F51', '1F6M', '1FAK', '1FC2', '1FCC', '1FFW', '1FLE', '1FQ1', '1FQJ', '1FSK', '1GCQ', '1GHQ', '1GL1', '1GLA', '1GP2', '1GPW', '1GRN', '1GXD', '1H1V', '1H9D', '1HCF', '1HE1', '1HE8', '1HIA', '1I2M', '1I4D', '1I9R', '1IB1', '1IBR', '1IJK', '1IQD', '1J2J', '1JIW', '1JK9', '1JMO', '1JPS', '1JTD', '1JTG', '1JWH', '1JZD', '1K4C', '1K5D', '1K74', '1KAC', '1KKL', '1KLU', '1KTZ', '1KXP', '1KXQ', '1LFD', '1M10', '1M27', '1MAH', '1ML0', '1MLC', '1MQ8', '1NCA', '1NSN', '1NW9', '1OC0', '1OFU', '1OPH', '1OYV', '1PPE', '1PVH', '1PXV', '1QA9', '1QFW', '1R0R', '1R6Q', '1R8S', '1RKE', '1RLB', '1RV6', '1S1Q', '1SBB', '1SYX', '1T6B', '1TMQ', '1UDI', '1US7', '1VFB', '1WEJ', '1WQ1', '1XD3', '1XQS', '1XU1', '1Z0K', '1Z5Y', '1ZHH', '1ZHI', '1ZLI', '2A5T', '2A9K', '2ABZ', '2AJF', '2AYO', '2B42', '2B4J', '2BTF', '2C0L', '2CFH', '2FD6', '2FJU', '2G77', '2GAF', '2GTP', '2HLE', '2HQS', '2HRK', '2I25', '2I9B', '2IDO', '2J0T', '2J7P', '2JEL', '2MTA', '2NZ8', '2O3B', '2O8V', '2OOB', '2OOR', '2OT3', '2OZA', '2PCC', '2SIC', '2SNI', '2UUY', '2VDB', '2VXT', '2W9E', '2X9A', '2YVJ', '2Z0E', '3A4S', '3AAA', '3AAD', '3BIW', '3BP8', '3BX7', '3CPH', '3D5S', '3DAW', '3EO1', '3EOA', '3F1P', '3FN1', '3G6D', '3H11', '3H2V', '3HMX', '3K75', '3L5W', '3L89', '3LVK', '3MXW', '3P57', '3PC8', '3RVW', '3S9D', '3SGQ', '3SZK', '3V6Z', '3VLB', '4CPA', '4DN4', '4G6M', '4H03', '4HX3', '4IZ7', '4JCV', '4LW4', '4M76', '7CEI', '9QFW']

# %%
import numpy as np

length = len(data_all)
x_labels = (list(data_all['PDB']))

# Set plot parameters
fig, ax = plt.subplots(figsize=(6, 30))
width = 0.4 # width of bar
x = np.arange(length)

ax.barh(x, list(data_all['rigid_inter_iRMSD_end']), width, color='#000080', label='rigid')
ax.barh(x + width, list(data_all['inter_iRMSD_end']), width, color='#73C2FB', label='flexible')
#ax.bar(x + (2 * width), list(data_all['inter_iRMSD_end']), width, color='#6593F5', label='Case-3')
#ax.bar(x + (3 * width), list(data_all['inter_iRMSD_end']), width, color='#0F52BA', label='Case-4')

ax.set_xlabel(r'inter-iRMSD [$\AA$]')
ax.set_xlim(0,10)
ax.set_yticks(x + width/2)
ax.set_yticklabels(x_labels)
ax.set_ylim(-0.5,x.size)
ax.invert_yaxis()
#ax.set_yticklabels(x_labels, rotation=90)
#ax.set_xlabel('Sample')
ax.set_title('iRMSD after Refinement')
ax.legend()
plt.grid(False, 'major', 'y', ls='--', lw=.5, c='k', alpha=.3)

fig.tight_layout()
plt.show()
